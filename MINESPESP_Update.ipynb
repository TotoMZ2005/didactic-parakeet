# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Solo versiones +1.17
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - Para versiones antiguas, ya esta disponible a exepcion de forge, seguir los pasos para usar un forge antiguo



version = '1.20.1' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - oldforge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO] Solo para versiones antiguas -1.17
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit) 1.20.1 29/09/24 ultima version disponible
# - catserver (Versión de Minecraft que combina Forge y Bukkit) 1.18.2 29/09/24 ultima version disponible
# - purpur (Versión de Minecraft que combina paper y Bukkit)

# Para usar paper primero tienes que instalar el vanilla
# Para usar mohist primero tienes que instalar el forge
# Para usar catserver primero tienes que instalar el forge
# Para usar purpur primero tienes que instalar el fabric

server_type = 'mohist'

#Importa librerias necesarias para el funcionamiento del script 

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor 

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

elif server_type == 'forge':
    serverURL = "https://api.serverjars.com/api/fetchJar/modded/forge/" + version

elif server_type == 'vanilla':
    serverURL = "https://api.serverjars.com/api/fetchJar/vanilla/vanilla/" + version

elif server_type == 'snapshot':
    serverURL = "https://api.serverjars.com/api/fetchJar/vanilla/snapshot/" + version

elif server_type == 'fabric':
    serverURL = 'https://api.serverjars.com/api/fetchJar/modded/fabric/' + version

elif server_type == 'mohist':
    serverURL = "https://api.serverjars.com/api/fetchJar/modded/mohist/" + version
    
elif server_type == 'catserver':
    serverURL = "https://api.serverjars.com/api/fetchJar/modded/catserver/" + version

elif server_type == 'purpur':
    serverURL = "https://api.serverjars.com/api/fetchJar/servers/purpur/" + version

# Lista de nombres de los archivos

jar_name = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar", 
            'catserver': "catserver.jar", 'purpur': "purpur.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-server-launch.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

if server_type == 'vanilla':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar vanilla.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# Descargando el tipo de servidor:
# Descargando a GitHub Codespaces...
# Completado!

# %%
#Tienes que poner el spawn proteccion en 0 para que puedas jugar de manera normal(esto dentro de Server.properties)
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading

import subprocess


#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)

# Instalar OpenJDK

version = colabconfig["server_version"]

# Ejecuta un comando en la terminal

def installjava17(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 17 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 17")

def installjava11(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 11 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 11")

def installjava8(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 8 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 8")
        
def purgejava(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK purgado correctamente")
    else:
        print("Fallo al purgar OpenJDK")

# Instala OpenJDK 17 si la versión de Minecraft es 1.17 o superior
# Si la versión es inferior, instala OpenJDK 8

if version < "1.14":
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 8
    installjava8('sudo apt-get install openjdk-8-jre-headless -y')

elif version >= "1.14" and version < "1.17":
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 11
    installjava11('sudo apt-get install openjdk-11-jre-headless -y')

else:
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 17
    installjava17('sudo apt-get install openjdk-17-jre-headless -y')

# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

#Lista de posibles archivos .jar

jar_list = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar", 'catserver': "catserver.jar", 'purpur': "purpur.jar"}

jar_name = jar_list[colabconfig["server_type"]]

# Argumentos de java.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok  #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2LDlO3CpY6m4M2eh6Pgj2IGsKfH_4yWWFtfSFFRdpiEJBPpNF" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))


elif tunnel_service == "playit":

    subprocess.run(["curl", "-SsL", "https://playit-cloud.github.io/ppa/key.gpg"], check=True)
    subprocess.run(["sudo", "apt-key", "add", "key.gpg"], check=True)

    # Añadiendo el repositorio de Playit.gg
    subprocess.run(["sudo", "curl", "-SsL", "-o", "/etc/apt/sources.list.d/playit-cloud.list", "https://playit-cloud.github.io/ppa/playit-cloud.list"], check=True)

    # Actualizando la lista de paquetes
    subprocess.run(["sudo", "apt", "update"], check=True)

    # Instalando Playit.gg
    result = subprocess.run(["sudo", "apt", "install", "playit"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)

    # Comprueba si la instalación fue exitosa
    if result.returncode == 0:
        print("Playit.gg installed")
    else:
        print("Failed to install Playit.gg")

    # Iniciando el servidor con Playit.gg
    print('Starting server...')
    subprocess.run(["playit", "&", "java", "$memory_allocation", "$server_flags", "-jar", "$jar_name", "nogui"], check=True)

    # Obteniendo la IP del servidor
    result = subprocess.run(["playit", "status"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print("Tu ip es: " + result.stdout.decode())

#Obtiene la lista de usuarios de JSONPlaceholder
#Para mantener el servidor activo
def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

#Obtener el archivo de configuracion
stype = colabconfig["server_type"]
version = colabconfig["server_version"]

#Imprimir el tipo de servidor y la version
print("Estas jugando a minecraft: " + stype + " en su version: "+ version)

#Si el servidor es de tipo Forge antiguo no va a funcionar
if colabconfig["server_type"] == "forge" and colabconfig["server_version"] < "1.17.1":
    print("La version de Forge no es compatible con este script. Por favor, usa una version de Forge 1.17.1 o superior.")


#Si el servidor es de tipo Forge encontrara los archivos necesarios para ejecutar el servidor

if colabconfig["server_type"] == "forge":

    # Obtiene la versión de Forge
    
    forgefiles = f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/"
    
    forgepreversion = os.listdir(forgefiles)
        
    if forgepreversion:
        
        forgeversion = forgepreversion[0]
        forgeversionchecked = forgeversion.replace(".jar", "")
        print("La versión de Forge es:", forgeversionchecked)
        
    else:
        
        print("No se encontraron archivos en el directorio Forge.")
        
    pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{forgeversionchecked}/unix_args.txt")

    if pathtoforge: # Checa si la lista no esta vacia

        path = pathtoforge[0] # Obtiene la primera ruta de la lista

        print(path)

        # !java @user_jvm_args.txt "@{path}" "$@"

    else:

        print("No se encontro el archivo unix_args.txt.")

#Si el servidor es de tipo Vanilla o paper o mohist o catserver o fabric o purpur

else:

    #Ejecuta el archivo jar del servidor
    
    # !java $memory_allocation $server_flags -jar $jar_name nogui

# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)  # Espera 1 minuto
# Out:
# el apt cache fue actualizado correctamente
# banned-ips.json      forge.jar	    mundo	       user_jvm_args.txt
# banned-players.json  forge.jar.log  ops.json	       usercache.json
# bukkit.yml	     help.yml	    permissions.yml    usernamecache.json
# colabconfig.json     libraries	    plugins	       whitelist.json
# commands.yml	     logs	    run.bat	       world
# config		     mods	    run.sh
# defaultconfigs	     mohist-config  server.properties
# eula.txt	     mohist.jar     spigot.yml
# OpenJDK purgado correctamente
# OpenJDK 17 instalado correctamente
# Usando ngrok
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# La IP de tu servidor es 4.tcp.ngrok.io:15292
# Estas jugando a minecraft: mohist en su version: 1.20.1
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
#
#  ███╗   ███╗  ██████╗  ██╗  ██╗ ██╗ ███████╗ ████████╗
#  ████╗ ████║ ██╔═══██╗ ██║  ██║ ██║ ██╔════╝ ╚══██╔══╝
#  ██╔████╔██║ ██║   ██║ ███████║ ██║ ███████╗    ██║
#  ██║╚██╔╝██║ ██║   ██║ ██╔══██║ ██║ ╚════██║    ██║
#  ██║ ╚═╝ ██║ ╚██████╔╝ ██║  ██║ ██║ ███████║    ██║
#  ╚═╝     ╚═╝  ╚═════╝  ╚═╝  ╚═╝ ╚═╝ ╚══════╝    ╚═╝
#
# Thanks for using Mohist - 1.20.1-689, Java(21.0.2) 65.0 PID: 56136
# Update in check...
# If you don't want to enable update check, set check_update in mohist-config/mohist.yml to false
# No update found, latest version: (689) current version: (689)
# Checking libraries, please wait...
# All libraries are nice :)!
# Searching incompatible mods...
# [18:38:49 INFO]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 47.2.30, --fml.mcVersion, 1.20.1, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20230612.114412, nogui]
# [18:38:49 INFO]: ModLauncher 10.0.9+10.0.9+main.dcd20f30 starting: java version 21.0.2 by Microsoft; OS Linux arch amd64 version 6.2.0-1019-azure
# [18:38:53 INFO]: ImmediateWindowProvider not loading because launch target is forgeserver
# [18:38:53 INFO]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%23112!/ Service=ModLauncher Env=SERVER
# [18:38:53 INFO]: Found 7 dependencies adding them to mods collection
# [18:38:56 INFO]: Compatibility level set to JAVA_17
# [18:38:56 INFO]: Launching target 'forgeserver' with arguments [nogui]
# [18:38:56 WARN]: Reference map 'handcrafted-forge-1.20.1-forge-refmap.json' for handcrafted.mixins.json could not be read. If this is a development environment you can ignore this message
# [18:38:56 WARN]: Reference map '${refmap_target}refmap.json' for corgilib.forge.mixins.json could not be read. If this is a development environment you can ignore this message
# [18:38:56 INFO]: Loading 44 mods:
# 	- another_furniture 1.20.1-3.0.1
# 	- argentinas_delight 1.1
# 	- caelus 3.1.0+1.20
# 	- corgilib 4.0.0.4
# 	- cosmeticarmorreworked 1.20.1-v1a
# 	- create 0.5.1.f
# 	- creativecore 2.11.25
# 	- cristellib 1.1.5
# 	- curios 5.7.2+1.20.1
# 	- dungeons_arise 2.1.57-1.20.1
# 	- enhancedcelestials 5.0.0.2
# 	- exposure 1.4.1
# 	- fallingtree 4.3.4
# 	- flywheel 0.6.10-7
# 	- forge 47.2.30
# 	- framework 0.6.27
# 	- geckolib 4.4.4
# 	- handcrafted 3.0.5
# 	- iceberg 1.1.16
# 	- immersive_aircraft 0.7.5+1.20.1
# 	- jackseconomy 1.2
# 	- jade 11.7.1
# 	- jeg 0.2.0
# 	- jei 15.3.0.4
# 	- man 1.2.4
# 	- measurements 2.0.0
# 	- minecraft 1.20.1
# 	- moa_decor_science 1.20.1
# 	- mohist 1.20.1
# 	- mr_dungeons_andtaverns 1-v2.1.4
# 	- parcool 1.20.1-3.1.0.6-R
# 	- playeranimator 1.0.2-rc1+1.20
# 	- playerrevive 2.0.24
# 	- puzzlesaccessapi 8.0.7
# 	- puzzleslib 8.1.18
# 	- resourcefullib 2.1.1
# 	- spectre 1.0.0
# 	- structure_gel 2.16.0
# 	- terrablender 3.0.1.4
# 	- trapcraft 2.10.2
# 	- travelersbackpack 9.1.12
# 	- twilightforest 4.3.2145
# 	- worldedit 7.2.15+6463-5ca4dff
# 	- xaerominimap 24.1.1
# [18:38:56 WARN]: Reference map 'jackseconomy.refmap.json' for jackseconomy.mixins.json could not be read. If this is a development environment you can ignore this message
# [18:38:56 WARN]: Reference map 'cristellib-forge-refmap.json' for cristellib.mixins.json could not be read. If this is a development environment you can ignore this message
# [18:39:10 INFO]: Constructing common components for puzzleslib:main
# [18:39:10 INFO]: Mohist mod loading.....
# [18:39:10 INFO]: Forge mod loading, version 47.2.30, for MC 1.20.1 with MCP 20230612.114412
# [18:39:10 INFO]: MinecraftForge v47.2.30 Initialized
# [18:39:10 INFO]: NeoForge v47.2.30 Initialized
# [18:39:10 INFO]: EventDispatcherRegistry initialized
# [18:39:17 INFO]: [structure_gel] Registering data for structure_gel:loot_table_alias
# [18:39:17 INFO]: [structure_gel] Registering data for structure_gel:data_handler_type
# [18:39:17 INFO]: [structure_gel] Registering data for structure_gel:dynamic_spawner
# [18:39:17 INFO]: [structure_gel] Registering data for structure_gel:jigsaw_type
# [18:39:17 INFO]: Initialized enhancedcelestials network!
# [18:39:17 INFO]: Initializing network...
# [18:39:17 INFO]: Initialized network!
# [18:39:17 INFO]: Got request to register class com.sk89q.worldedit.forge.ForgePlatform with WorldEdit [com.sk89q.worldedit.extension.platform.PlatformManager@74582731]
# [18:39:17 INFO]: WorldEdit for Forge (version 7.2.15+6463-5ca4dff) is loaded
# [18:39:17 INFO]: Registered synced data key jeg:aiming for minecraft:player
# [18:39:17 INFO]: Registered synced data key jeg:reloading for minecraft:player
# [18:39:17 INFO]: Registered synced data key jeg:shooting for minecraft:player
# [18:39:18 INFO]: Registered the FluidEffect with Unique ID of minecraft:water for Water (Fluid Amount Required: 1000) with the ID 0
# [18:39:18 INFO]: Registered the FluidEffect with Unique ID of minecraft:lava for Lava (Fluid Amount Required: 1000) with the ID 1
# [18:39:18 INFO]: Registered the FluidEffect with Unique ID of travelersbackpack:potion for Uncraftable Potion (Fluid Amount Required: 250) with the ID 2
# [18:39:18 INFO]: Registered the FluidEffect with Unique ID of minecraft:milk for Milk (Fluid Amount Required: 1000) with the ID 3
# [18:39:18 INFO]: Loading Xaero's Minimap - Stage 1/2 (Server)
# [18:39:18 INFO]: Loading Xaero's Minimap - Stage 2/2 (Server)
# [18:39:18 INFO]: Start loading plugin at snownee.jade.addon.vanilla.VanillaPlugin
# [18:39:18 INFO]: Start loading plugin at snownee.jade.addon.universal.UniversalPlugin
# [18:39:18 INFO]: Start loading plugin at snownee.jade.addon.core.CorePlugin
# [18:39:18 INFO]: Start loading plugin at twilightforest.compat.jade.JadeCompat
# [18:39:22 INFO]: Environment: authHost='https://authserver.mojang.com', accountsHost='https://api.mojang.com', sessionHost='https://sessionserver.mojang.com', servicesHost='https://api.minecraftservices.com', name='PROD'
# [18:39:27 ERROR]: Cristel Lib Config Pack has no data
# [18:39:28 INFO]: Registering commands with com.sk89q.worldedit.forge.ForgePlatform
# [18:39:29 INFO]: Loaded 31 recipes
# [18:39:30 INFO]: Loaded 3354 advancements
# [18:39:30 INFO]: Loaded 11 curio slots
# [18:39:30 INFO]: Loaded 1 curio entities
# [18:39:30 INFO]: Loaded 9 Stalactite configs!
# [18:39:33 INFO]: Starting minecraft server version 1.20.1
# [18:39:33 INFO]: Loading properties
# [18:39:33 INFO]: Default game type: SURVIVAL
# [18:39:33 INFO]: Generating keypair
# [18:39:33 INFO]: Starting Minecraft server on *:25565
# [18:39:33 INFO]: Using epoll channel type
# [18:39:34 INFO]: This server is running Mohist version 1.20.1-689 (MC: 1.20.1) (Implementing API version 1.20.1-R0.1-SNAPSHOT, Forge version 47.2.30, NeoForge version 47.1.79)
# [18:39:35 INFO]: Debug logging is enabled
# [18:39:35 INFO]: Server Ping Player Sample Count: 20
# [18:39:35 INFO]: Using 4 threads for Netty based IO
# [18:39:37 ERROR]: Could not load 'plugins/worldguard-bukkit-7.0.9-dist (2).jar' in folder 'plugins'
# org.bukkit.plugin.UnknownDependencyException: Unknown dependency WorldEdit. Please download and install WorldEdit to run this plugin.
# 	at org.bukkit.plugin.SimplePluginManager.loadPlugins(SimplePluginManager.java:271) ~[forge-1.20.1-47.2.30-universal.jar%23279!/:?]
# 	at org.bukkit.craftbukkit.v1_20_R1.CraftServer.loadPlugins(CraftServer.java:436) ~[forge-1.20.1-47.2.30-universal.jar%23279!/:997de31d-ddc9a2dad-d2eba2c8-47.1.79]
# 	at net.minecraft.server.dedicated.DedicatedServer.m_7038_(DedicatedServer.java:216) ~[server-1.20.1-20230612.114412-srg.jar%23274!/:?]
# 	at net.minecraft.server.MinecraftServer.m_130011_(MinecraftServer.java:848) ~[server-1.20.1-20230612.114412-srg.jar%23274!/:?]
# 	at net.minecraft.server.MinecraftServer.m_206580_(MinecraftServer.java:281) ~[server-1.20.1-20230612.114412-srg.jar%23274!/:?]
# 	at java.lang.Thread.run(Thread.java:1583) [?:?]
# [18:39:39 INFO]: [LuckPerms] Loading LuckPerms v5.4.102
# [18:39:40 INFO]: [Essentials] Loading Essentials v2.21.0-dev+78-c60ed56
# [18:39:40 INFO]: [PlaceholderAPI] Loading PlaceholderAPI v2.11.5
# [18:39:40 INFO]: [Multiverse-Core] Loading Multiverse-Core v4.3.1-b861
# [18:39:40 INFO]: [ProtocolLib] Loading ProtocolLib v5.2.0-SNAPSHOT-679
# [18:39:40 WARN]: [ProtocolLib] Loaded class javax.annotation.Nonnull from DiscordSRV v1.27.0 which is not a depend or softdepend of this plugin.
# [18:39:43 INFO]: [RedProtect] Loading RedProtect v8.1.1-SNAPSHOT
# [18:39:43 INFO]: [Shopkeepers] Loading Shopkeepers v2.19.0
# [18:39:44 INFO]: [Shopkeepers] Loaded all plugin classes (1117 ms).
# [18:39:44 INFO]: [Shopkeepers] Loading config.
# [18:39:44 WARN]: [Shopkeepers] Config: Forcefully enabled 'disable-inventory-verification' to resolve a known incompatibility with Mohist servers.
# [18:39:44 INFO]: [Shopkeepers] Loading language file: language-en-default.yml
# [18:39:44 INFO]: [Shopkeepers] Registering defaults.
# [18:39:44 INFO]: [DiscordSRV] Loading DiscordSRV v1.27.0
# [18:39:44 INFO]: [SimplePortals] Loading SimplePortals v1.7.5
# [18:39:44 INFO]: [ConditionalEvents] Loading ConditionalEvents v4.50.1
# [18:39:44 INFO]: [LuckPerms] Enabling LuckPerms v5.4.102
# [18:39:45 INFO]:         __
# [18:39:45 INFO]:   |    |__)   LuckPerms v5.4.102
# [18:39:45 INFO]:   |___ |      Running on Bukkit - Mohist
# [18:39:45 INFO]:
# [18:39:45 INFO]: [LuckPerms] Loading configuration...
# [18:39:46 INFO]: [LuckPerms] Loading storage provider... [H2]
# [18:39:48 INFO]: [LuckPerms] Loading internal permission managers...
# [18:39:48 INFO]: [LuckPerms] Performing initial data load...
# [18:39:48 INFO]: [LuckPerms] Successfully enabled. (took 4198ms)
# [18:39:48 INFO]: [ProtocolLib] Enabling ProtocolLib v5.2.0-SNAPSHOT-679
# [18:39:49 INFO]: Loading server configs...
# [18:39:49 INFO]: Registered region minecraft:overworld to index 0 for type OVERWORLD
# [18:39:49 INFO]: Registered region minecraft:nether to index 0 for type NETHER
# [18:39:49 INFO]: Initialized TerraBlender biomes for level stem minecraft:the_nether
# [18:39:49 INFO]: Preparing level "world"
# [18:39:49 INFO]: Preparing start region for dimension minecraft:overworld
# [18:39:50 INFO]: Preparing spawn area: 0%
# [18:39:51 INFO]: Preparing spawn area: 0%
# [18:39:51 INFO]: Preparing spawn area: 0%
# [18:39:51 INFO]: Preparing spawn area: 0%
# [18:39:51 INFO]: Preparing spawn area: 4%
# [18:39:52 INFO]: Preparing spawn area: 87%
# [18:39:52 INFO]: Time elapsed: 2573 ms
# [18:39:52 INFO]: Preparing start region for dimension twilightforest:twilight_forest
# [18:39:52 INFO]: Preparing spawn area: 0%
# [18:39:52 INFO]: Preparing spawn area: 0%
# [18:39:53 INFO]: Preparing spawn area: 1%
# [18:39:53 INFO]: Preparing spawn area: 10%
# [18:39:54 INFO]: Preparing spawn area: 17%
# [18:39:54 INFO]: Time elapsed: 2497 ms
# [18:39:54 INFO]: Preparing start region for dimension minecraft:the_nether
# [18:39:55 INFO]: Preparing spawn area: 0%
# [18:39:55 INFO]: Preparing spawn area: 0%
# [18:39:56 INFO]: Preparing spawn area: 0%
# [18:39:56 INFO]: Preparing spawn area: 64%
# [18:39:56 INFO]: Time elapsed: 1644 ms
# [18:39:56 INFO]: Preparing start region for dimension man:halucination
# [18:39:56 INFO]: Preparing spawn area: 0%
# [18:39:57 INFO]: Preparing spawn area: 0%
# [18:39:57 INFO]: Preparing spawn area: 5%
# [18:39:58 INFO]: Preparing spawn area: 22%
# [18:39:58 INFO]: Time elapsed: 1844 ms
# [18:39:58 INFO]: Preparing start region for dimension minecraft:the_end
# [18:39:59 INFO]: Preparing spawn area: 0%
# [18:39:59 INFO]: Preparing spawn area: 0%
# [18:39:59 INFO]: Preparing spawn area: 0%
# [18:39:59 INFO]: Preparing spawn area: 70%
# [18:40:00 INFO]: Time elapsed: 1614 ms
# [18:40:00 INFO]: [Essentials] Enabling Essentials v2.21.0-dev+78-c60ed56
# [18:40:00 ERROR]: You are running a server that does not properly support Bukkit plugins. Bukkit plugins should not be used with Forge/Fabric mods! For Forge: Consider using ForgeEssentials, or SpongeForge + Nucleus.
# [18:40:00 INFO]: Status determining class: brand:Mohist
# [18:40:00 INFO]: Attempting to convert old kits in config.yml to new kits.yml
# [18:40:00 INFO]: No kits found to migrate.
# [18:40:01 INFO]: Loaded 39095 items from items.json.
# [18:40:01 INFO]: Using locale en
# [18:40:01 INFO]: ServerListPingEvent: Spigot iterator API
# [18:40:01 INFO]: Starting Metrics. Opt-out using the global bStats config.
# [18:40:01 WARN]: Detected supported permissions plugin LuckPerms without Vault installed.
# [18:40:01 WARN]: Features such as chat prefixes/suffixes and group-related functionality will not work until you install Vault.
# [18:40:01 INFO]: Using superperms-based permissions.
# [18:40:01 INFO]: [PlaceholderAPI] Enabling PlaceholderAPI v2.11.5
# [18:40:02 INFO]: [PlaceholderAPI] Fetching available expansion information...
# [18:40:02 INFO]: [PlaceholderAPI] Successfully registered internal expansion: mohist [1.20.1]
# [18:40:02 INFO]: Hook PlaceholderAPI!
# [18:40:02 INFO]: [Multiverse-Core] Enabling Multiverse-Core v4.3.1-b861
# [18:40:02 WARN]: [Multiverse-Core] "Multiverse-Core v4.3.1-b861" has registered a listener for org.bukkit.event.entity.EntityCreatePortalEvent on method "public void com.onarandombox.MultiverseCore.listeners.MVPortalListener.entityPortalCreate(org.bukkit.event.entity.EntityCreatePortalEvent)", but the event is Deprecated. "Server performance will be affected"; please notify the authors [dumptruckman, Rigby, fernferret, lithium3141, main--].
# [18:40:02 INFO]: [Multiverse-Core] We are aware of the warning about the deprecated event. There is no alternative that allows us to do what we need to do and performance impact is negligible. It is safe to ignore.
# [18:40:02 WARN]: [Multiverse-Core] Exception while loading value for environment
# [18:40:02 WARN]: [Multiverse-Core] Exception while loading value for environment
# [18:40:02 WARN]: [Multiverse-Core] Exception while loading value for environment
# [18:40:02 WARN]: [Multiverse-Core] Exception while loading value for environment
# [18:40:02 WARN]: [Multiverse-Core] Exception while loading value for environment
# [18:40:02 WARN]: [Multiverse-Core] Exception while loading value for environment
# [18:40:02 WARN]: [Multiverse-Core] Exception while loading value for environment
# [18:40:02 WARN]: [Multiverse-Core] Exception while loading value for environment
# [18:40:02 WARN]: [Multiverse-Core] Exception while loading value for environment
# [18:40:02 WARN]: [Multiverse-Core] Exception while loading value for environment
# [18:40:02 WARN]: [Multiverse-Core] Exception while loading value for environment
# [18:40:02 WARN]: [Multiverse-Core] Exception while loading value for environment
# [18:40:02 WARN]: [Multiverse-Core] Exception while loading value for environment
# [18:40:02 WARN]: [Multiverse-Core] Exception while loading value for environment
# [18:40:02 WARN]: [Multiverse-Core] WorldManager: Can't load this world because the folder was deleted/moved: southern
# [18:40:02 WARN]: [Multiverse-Core] Use '/mv remove' to remove it from the config!
# [18:40:02 WARN]: [Multiverse-Core] WorldManager: Can't load this world because the folder was deleted/moved: lobby-1
# [18:40:02 WARN]: [Multiverse-Core] Use '/mv remove' to remove it from the config!
# [18:40:02 WARN]: [Multiverse-Core] WorldManager: Can't load this world because the folder was deleted/moved: past
# [18:40:02 WARN]: [Multiverse-Core] Use '/mv remove' to remove it from the config!
# [18:40:02 WARN]: [Multiverse-Core] WorldManager: Can't load this world because the folder was deleted/moved: after_place
# [18:40:02 WARN]: [Multiverse-Core] Use '/mv remove' to remove it from the config!
# [18:40:02 INFO]: Preparing start region for dimension minecraft:mundo
# [18:40:03 INFO]: Preparing spawn area: 0%
# [18:40:03 INFO]: Preparing spawn area: 0%
# [18:40:03 INFO]: Preparing spawn area: 0%
# [18:40:03 INFO]: Preparing spawn area: 0%
# [18:40:04 INFO]: Preparing spawn area: 0%
# [18:40:05 INFO]: Preparing spawn area: 0%
# [18:40:05 INFO]: Preparing spawn area: 4%
# [18:40:05 INFO]: Time elapsed: 3507 ms
# [18:40:05 WARN]: [Multiverse-Core] WorldManager: Can't load this world because the folder was deleted/moved: lobby2
# [18:40:05 WARN]: [Multiverse-Core] Use '/mv remove' to remove it from the config!
# [18:40:05 WARN]: [Multiverse-Core] WorldManager: Can't load this world because the folder was deleted/moved: northern
# [18:40:05 WARN]: [Multiverse-Core] Use '/mv remove' to remove it from the config!
# [18:40:05 WARN]: [Multiverse-Core] WorldManager: Can't load this world because the folder was deleted/moved: lobby1
# [18:40:05 WARN]: [Multiverse-Core] Use '/mv remove' to remove it from the config!
# [18:40:05 WARN]: [Multiverse-Core] WorldManager: Can't load this world because the folder was deleted/moved: lobby
# [18:40:05 WARN]: [Multiverse-Core] Use '/mv remove' to remove it from the config!
# [18:40:05 WARN]: [Multiverse-Core] WorldManager: Can't load this world because the folder was deleted/moved: the_aether
# [18:40:05 WARN]: [Multiverse-Core] Use '/mv remove' to remove it from the config!
# [18:40:05 INFO]: [Multiverse-Core] 6 - World(s) loaded.
# [18:40:05 WARN]: [Multiverse-Core] Buscript failed to load! The script command will be disabled! If you would like not to see this message, use `/mv conf enablebuscript false` to disable Buscript from loading.
# [18:40:06 INFO]: [Multiverse-Core] Version 4.3.1-b861 (API v24) Enabled - By dumptruckman, Rigby, fernferret, lithium3141 and main--
# [18:40:06 INFO]: [RedProtect] Enabling RedProtect v8.1.1-SNAPSHOT
# [18:40:06 INFO]: [RedProtect] Server version: 1.20.1-R0.1-SNAPSHOT
# [18:40:06 INFO]: [RedProtect] All configurations loaded!
# [18:40:06 INFO]: [RedProtect] Language file loaded - Using: EN-US
# [18:40:06 INFO]: [RedProtect] Registering commands...
# [18:40:06 INFO]: [RedProtect] Registering listeners...
# [18:40:06 INFO]: [RedProtect] Essentials found. Hooked.
# [18:40:06 INFO]: [PlaceholderAPI] Successfully registered internal expansion: redprotect [8.1.1-SNAPSHOT]
# [18:40:06 INFO]: [RedProtect] PlaceHolderAPI found. Hooked and registered some chat placeholders.
# [18:40:06 INFO]: [RedProtect] - Loading world's regions...
# [18:40:06 INFO]: [RedProtect] - Loading twilight_forest's regions...
# [18:40:06 INFO]: [RedProtect] - Loading DIM-1's regions...
# [18:40:06 INFO]: [RedProtect] - Loading halucination's regions...
# [18:40:06 INFO]: [RedProtect] - Loading DIM1's regions...
# [18:40:06 INFO]: [RedProtect] - Loading mundo's regions...
# [18:40:06 INFO]: [RedProtect] Auto-save Scheduler: Saving file database every 60 minutes!
# [18:40:06 INFO]: [RedProtect] There are 0 regions on (file) database!
# [18:40:06 INFO]: [RedProtect] Helper version: Latest
# [18:40:06 INFO]: [RedProtect] Loading GuiFlags for 1.14+
# [18:40:06 INFO]: [RedProtect] Metrics enabled! See our stats here: https://bstats.org/plugin/bukkit/RedProtect
# [18:40:06 INFO]: [RedProtect] Loading API...
# [18:40:06 INFO]: [RedProtect] API Loaded!
# [18:40:06 INFO]:  _   _  _   _   _   _  _ _  _  _ _ _  _
# [18:40:06 INFO]: |_| |_ | \ |_| |_| | |  |  |_ |   |  |_|
# [18:40:06 INFO]: | \ |_ |_/ |   | \ |_|  |  |_ |_  |  |_|
# [18:40:06 INFO]: » RedProtect v8.1.1-SNAPSHOT enabled
# [18:40:06 INFO]:
# [18:40:06 INFO]: [Shopkeepers] Enabling Shopkeepers v2.19.0
# [18:40:07 INFO]: [Shopkeepers] Loading the data of 12 shopkeepers ...
# [18:40:07 INFO]: [DiscordSRV] Enabling DiscordSRV v1.27.0
# [18:40:07 INFO]: [SimplePortals] Enabling SimplePortals v1.7.5
# [18:40:07 INFO]: [SimplePortals] Everything inside the configuration seems to be up to date. (Took 4ms)
# [18:40:07 INFO]: [SimplePortals] Packets have been setup for v1_20_R1!
# [18:40:07 INFO]: [SimplePortals] Everything looks like it is up to date!
# [18:40:07 INFO]: [ConditionalEvents] Enabling ConditionalEvents v4.50.1
# [18:40:07 INFO]: [PlaceholderAPI] Successfully registered internal expansion: conditionalevents [4.50.1]
# [18:40:07 INFO]: [ConditionalEvents] Has been enabled! Version: 4.50.1
# [18:40:07 INFO]: [ConditionalEvents] Thanks for using my plugin!   ~Ajneb97
# [18:40:08 INFO]: [Mohist] Enabling Mohist v1.20.1
# [18:40:08 INFO]: [DiscordSRV] DiscordSRV is up-to-date. (6405e850eea61a4b9bf4f0d0cbb80fe20b3cfb90)
# [18:40:08 INFO]: Server permissions file permissions.yml is empty, ignoring it
# [18:40:08 INFO]: [PlaceholderAPI] Placeholder expansion registration initializing...
# [18:40:08 INFO]: Done (19.211s)! For help, type "help"
# [18:40:08 INFO]: Successfully initialized permission handler forge:default_handler
# [18:40:08 INFO]: Forwarding forge permission[forge:default_handler] to bukkit[mohist:permission]
# [18:40:10 INFO]: [DiscordSRV] [JDA] Login Successful!
# [18:40:10 INFO]: [DiscordSRV] [JDA] Connected to WebSocket
# [18:40:11 INFO]: [DiscordSRV] [JDA] Finished Loading!
# [18:40:11 INFO]: [DiscordSRV] Found server G:Server de TroloMz (Bot)(897200932243251282)
# [18:40:11 INFO]: [DiscordSRV] - TC:fotos-toto(1056467643114213448)
# [18:40:11 INFO]: [DiscordSRV] - TC:videos-toto(1104592811904479304)
# [18:40:11 INFO]: [DiscordSRV] - TC:landing-spot(1184634863551266862)
# [18:40:11 INFO]: [DiscordSRV] - TC:fotos-fortnite(1150142068375703713)
# [18:40:11 INFO]: [DiscordSRV] - TC:consola-mc(1231802208983715981)
# [18:40:11 INFO]: [DiscordSRV] - TC:╔『🚩』bienvenidas(898645772541779969)
# [18:40:11 INFO]: [DiscordSRV] - TC:║『🌟』nitro-boost(1197006115842555963)
# [18:40:11 INFO]: [DiscordSRV] - TC:╚『⭐』roles(897273525746954280)
# [18:40:11 INFO]: [DiscordSRV] - TC:╔『🔎』general(998634116977270795)
# [18:40:11 INFO]: [DiscordSRV] - TC:║-chat-mc(1231802587330641953)
# [18:40:11 INFO]: [DiscordSRV] - TC:mods-mc(1232454009395216384)
# [18:40:11 INFO]: [DiscordSRV] - TC:║ip-mc(1232816944823009331)
# [18:40:11 INFO]: [DiscordSRV] Console forwarding assigned to channel TC:consola-mc(1231802208983715981)
# [18:40:12 INFO]: [DiscordSRV] Enabling Essentials hook
# [18:40:12 INFO]: [DiscordSRV] Enabling LuckPerms hook
# [18:40:12 INFO]: [DiscordSRV] Enabling PlaceholderAPI hook
# [18:40:12 WARN]: [DiscordSRV] Could not set topic of channel TC:║-chat-mc(1231802587330641953) because the bot does not have the "Read Text Channels & See Voice Channels" permission
# [18:40:12 WARN]: [DiscordSRV] Could not set topic of channel TC:consola-mc(1231802208983715981) because the bot does not have the "Manage Channels" permission
# [18:40:14 INFO]: [PlaceholderAPI] Successfully registered external expansion: objective [4.2.0]
# [18:40:14 INFO]: [PlaceholderAPI] Successfully registered external expansion: player [2.0.8]
# [18:40:14 INFO]: 2 placeholder hook(s) registered!
# [18:40:14 INFO]: Fetching version information...
# [18:40:14 INFO]: [PlaceholderAPI] Successfully registered internal expansion: discordsrv [1.27.0]
# [18:40:15 INFO]: [DiscordSRV] Cleared all pre-existing slash commands in 1/1 guilds (0 cancelled)
# [18:40:15 WARN]: [DiscordSRV] Could not send message in channel TC:║-chat-mc(1231802587330641953) because the bot does not have the "Read Text Channels & See Voice Channels" permission
# [18:40:56 INFO]: TotoMZ joined the game
# [18:40:56 INFO]: Syncing config to TotoMZ (7ef1538f-792a-42bd-b310-3faedad50ab3)
# [18:40:56 INFO]: TotoMZ[/127.0.0.1:40110] logged in with entity id 451 at ([world]-513.4664504316966, 101.0, 263.145421190033)
# [18:40:57 WARN]: [DiscordSRV] Could not send message in channel TC:║-chat-mc(1231802587330641953) because the bot does not have the "Read Text Channels & See Voice Channels" permission
# [18:41:08 INFO]: TotoMZ issued server command: /gamemode c
# [18:41:18 INFO]: TotoMZ issued server command: /portal create mundo
# [18:41:28 INFO]: TotoMZ issued server command: /portal create mundo13212
# [18:41:35 INFO]: TotoMZ issued server command: /portals
# [18:41:39 INFO]: TotoMZ issued server command: /portals list
# [18:42:05 INFO]: TotoMZ issued server command: /mv tp mundo
# [18:42:09 INFO]: TotoMZ issued server command: /gamemode c
# [18:42:13 INFO]: TotoMZ issued server command: /portal create mundo
# [18:42:38 INFO]: TotoMZ issued server command: /mv tp world
# [18:42:50 INFO]: TotoMZ issued server command: /gamemode c
# [18:42:56 INFO]: TotoMZ issued server command: /portal sm
# [18:43:04 INFO]: TotoMZ issued server command: /portal create mundo
# [18:43:11 INFO]: TotoMZ issued server command: /mv tp mundo
# [18:43:14 INFO]: TotoMZ issued server command: /gamemode c
# [18:43:21 INFO]: TotoMZ issued server command: /portal setlocation mundo
# [18:43:25 INFO]: TotoMZ issued server command: /gamemode c
# [18:43:29 INFO]: TotoMZ issued server command: /lobby
# [18:43:35 INFO]: TotoMZ issued server command: /gamemodec
# [18:43:37 INFO]: TotoMZ issued server command: /gamemode C
# [18:44:11 INFO]: TotoMZ issued server command: //set 0
# [18:44:42 INFO]: TotoMZ issued server command: /gamemode c
# [18:44:56 INFO]: TotoMZ issued server command: /lobby
# [18:45:00 INFO]: TotoMZ issued server command: /gamemodec
# [18:45:02 INFO]: TotoMZ issued server command: /gamemode cv
# [18:45:04 INFO]: TotoMZ issued server command: /gamemode c
# [18:46:01 INFO]: TotoMZ issued server command: /portal fill mundo WATER
# [18:46:27 INFO]: TotoMZ issued server command: /give TotoMZ barrier
# [18:46:39 INFO]: TotoMZ issued server command: //set 0
# [18:46:50 INFO]: TotoMZ issued server command: //set 0
# [18:47:03 INFO]: TotoMZ issued server command: /portal fill mundo AIR
# [18:47:22 INFO]: TotoMZ issued server command: /lobby
# [18:47:40 INFO]: TotoMZ issued server command: /gamemode c
# [18:47:52 INFO]: TotoMZ has made the advancement [Ice Bucket Challenge]
# [18:47:52 WARN]: [DiscordSRV] Could not send message in channel TC:║-chat-mc(1231802587330641953) because the bot does not have the "Read Text Channels & See Voice Channels" permission
# [18:47:52 WARN]: [DiscordSRV] Could not send message in channel TC:║-chat-mc(1231802587330641953) because the bot does not have the "Read Text Channels & See Voice Channels" permission
# [18:47:52 WARN]: [DiscordSRV] Could not send message in channel TC:║-chat-mc(1231802587330641953) because the bot does not have the "Read Text Channels & See Voice Channels" permission
# [18:48:30 INFO]: TotoMZ issued server command: //copy
# [18:48:35 INFO]: TotoMZ issued server command: //paste
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [18:48:43 INFO]: TotoMZ issued server command: //rotate 90
# [18:48:45 INFO]: TotoMZ issued server command: //paste
# [18:48:49 INFO]: TotoMZ issued server command: //undo
# [18:48:50 INFO]: TotoMZ issued server command: //undo
# [18:49:03 INFO]: TotoMZ issued server command: /lobby
# [18:49:07 INFO]: TotoMZ issued server command: /gamemode c
# [18:49:16 INFO]: TotoMZ issued server command: //paste
# [18:49:18 INFO]: TotoMZ issued server command: //paste
# [18:49:20 INFO]: TotoMZ issued server command: //paste
# [18:49:20 ERROR]: POI data mismatch: never registered at BlockPos{x=-517, y=102, z=263}
# [18:49:21 INFO]: TotoMZ issued server command: //paste
# [18:49:24 INFO]: TotoMZ issued server command: //paste
# [18:49:34 INFO]: TotoMZ issued server command: //set 0
# [18:49:37 INFO]: TotoMZ issued server command: //paste
# [18:49:39 INFO]: TotoMZ issued server command: //paste
# [18:49:40 INFO]: TotoMZ issued server command: //paste
# [18:49:41 INFO]: TotoMZ issued server command: //paste
# [18:49:44 INFO]: TotoMZ issued server command: /
# [18:49:48 INFO]: TotoMZ issued server command: //paste
# [18:49:51 INFO]: TotoMZ issued server command: //paste
# [18:49:52 INFO]: TotoMZ issued server command: //paste
# [18:49:56 INFO]: TotoMZ issued server command: //paste
# [18:49:58 INFO]: TotoMZ issued server command: /
# [18:50:05 INFO]: TotoMZ issued server command: //paste
# [18:50:08 INFO]: TotoMZ issued server command: //paste
# [18:50:12 WARN]: [DiscordSRV] Could not set topic of channel TC:║-chat-mc(1231802587330641953) because the bot does not have the "Read Text Channels & See Voice Channels" permission
# [18:50:12 WARN]: [DiscordSRV] Could not set topic of channel TC:consola-mc(1231802208983715981) because the bot does not have the "Manage Channels" permission
# [18:50:12 INFO]: TotoMZ issued server command: //paste
# [18:50:13 INFO]: TotoMZ issued server command: //paste
# [18:50:17 INFO]: TotoMZ issued server command: //paste
# [18:50:21 INFO]: TotoMZ issued server command: //paste
# [18:50:25 INFO]: TotoMZ issued server command: //paste
# [18:50:27 INFO]: TotoMZ issued server command: //paste
# [18:50:31 INFO]: TotoMZ issued server command: //paste
# [18:50:32 INFO]: TotoMZ issued server command: //paste
# [18:50:33 INFO]: TotoMZ issued server command: //paste
# [18:50:40 INFO]: TotoMZ issued server command: //set 0
# [18:50:48 INFO]: TotoMZ issued server command: //paste
# [18:50:51 INFO]: TotoMZ issued server command: //set 0
# [18:50:54 INFO]: TotoMZ issued server command: //paste
# [18:50:58 INFO]: TotoMZ issued server command: //set 0
# [18:51:00 INFO]: TotoMZ issued server command: //paste
# [18:51:02 INFO]: TotoMZ issued server command: //paste
# [18:51:03 INFO]: TotoMZ issued server command: //paste
# [18:51:06 INFO]: TotoMZ issued server command: //set 0
# [18:51:08 INFO]: TotoMZ issued server command: //paste
# [18:51:09 INFO]: TotoMZ issued server command: //paste
# [18:51:12 INFO]: TotoMZ issued server command: //paste
# [18:51:22 INFO]: TotoMZ issued server command: //copy
# [18:51:25 INFO]: TotoMZ issued server command: //copy
# [18:51:29 INFO]: TotoMZ issued server command: //set 0
# [18:51:32 INFO]: TotoMZ issued server command: //paste
# [18:51:35 INFO]: TotoMZ issued server command: //set 0
# [18:51:38 INFO]: TotoMZ issued server command: //paste
# [18:51:41 INFO]: TotoMZ issued server command: //set 0
# [18:51:43 INFO]: TotoMZ issued server command: //paste
# [18:51:46 INFO]: TotoMZ issued server command: //set 0
# [18:51:48 INFO]: TotoMZ issued server command: //paste
# [18:52:22 INFO]: TotoMZ issued server command: /lobby
# [18:52:23 INFO]: TotoMZ issued server command: /gamemode c
# [18:52:28 INFO]: TotoMZ issued server command: /
# [18:52:31 INFO]: TotoMZ issued server command: //set 0
# [18:52:33 INFO]: TotoMZ issued server command: //set 0
# [18:52:43 INFO]: TotoMZ issued server command: //set 0
# [18:52:59 INFO]: TotoMZ issued server command: //set 0
# [18:53:11 INFO]: TotoMZ lost connection: Disconnected
# [18:53:11 INFO]: TotoMZ left the game
# [18:53:11 WARN]: [DiscordSRV] Could not send message in channel TC:║-chat-mc(1231802587330641953) because the bot does not have the "Read Text Channels & See Voice Channels" permission
# >
